# %%
bidblack = open('biden22520.txt', 'r', encoding='utf8').read()
print(bidblack[:40])
# Out:
# Well, I tell you what, I’m doing, I’m fo

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/nbuser/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk.data
from nltk import word_tokenize
from nltk.tokenize import Su
sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
sents = sent_detector.tokenize(bidblack.strip())
print(len(sents))

for sent in sents:
    print(len(sent))
# Out:
# 161
# 63
# 34
# 40
# 19
# 15
# 14
# 29
# 29
# 16
# 50
# 62
# 52
# 32
# 102
# 26
# 66
# 53
# 26
# 90
# 177
# 24
# 15
# 33
# 58
# 37
# 20
# 213
# 150
# 5
# 5
# 39
# 13
# 11
# 11
# 163
# 14
# 165
# 178
# 75
# 21
# 22
# 90
# 104
# 58
# 58
# 181
# 30
# 20
# 24
# 39
# 93
# 53
# 131
# 71
# 37
# 24
# 19
# 90
# 58
# 31
# 99
# 134
# 38
# 93
# 129
# 67
# 74
# 55
# 131
# 45
# 18
# 45
# 67
# 68
# 61
# 80
# 41
# 13
# 28
# 26
# 15
# 214
# 72
# 67
# 45
# 59
# 115
# 38
# 37
# 20
# 19
# 40
# 71
# 192
# 96
# 119
# 35
# 44
# 151
# 135
# 81
# 75
# 49
# 210
# 15
# 47
# 73
# 15
# 20
# 109
# 13
# 29
# 111
# 24
# 162
# 78
# 64
# 78
# 23
# 45
# 55
# 23
# 150
# 84
# 113
# 162
# 72
# 57
# 17
# 33
# 176
# 266
# 41
# 59
# 92
# 253
# 282
# 27
# 24
# 89
# 35
# 81
# 66
# 14
# 118
# 67
# 70
# 77
# 159
# 27
# 27
# 92
# 32
# 194
# 101
# 7
# 69
# 229
# 44
# 104
# 34

# %%
freq.plot(20, cumulative=False)
